# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#reading csvs from raw data sets
pop_df = pd.read_csv("cleaned_population.csv")
inventory_df = pd.read_csv("cleaned_inventory.csv")
rental_df = pd.read_csv("cleaned_rental.csv")

# %%
pop_df
# Out:
#      Unnamed: 0         City State  2018 Population  2019 Population  \
# 0             0  Birmingham     AL           210487           209403
# 1             1  Huntsville     AL           198125           200574
# 2             2      Mobile     AL           189809           188720
# 3             3  Montgomery     AL           198899           198525
# 4             4    Chandler     AZ           257186           261165
# ..          ...          ...   ...              ...              ...
# 177         177     Spokane     WA           219332           222081
# 178         178      Tacoma     WA           216111           217827
# 179         179   Vancouver     WA           182887           184463
# 180         180     Madison     WI           257854           259680
# 181         181   Milwaukee     WI           591375           590157
#
#     2020 Population
# 0           208,940
# 1           202,910
# 2           186,804
# 3           197,282
# 4           268,675
# ...

# %%
#rate
