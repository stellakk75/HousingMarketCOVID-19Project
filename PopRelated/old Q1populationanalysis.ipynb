# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as st

# %%
#reading csvs from cleaned data set
cleaned_pop_df = pd.read_csv("cleaned_population.csv")
cleaned_rental_df = pd.read_csv("cleaned_rental.csv")
cleaned_housing_df = pd.read_csv("cleaned_inventory.csv")

#top&bottom csvs
T_pop1819 = pd.read_csv("mostchangedpop18-19.csv")
T_pop1920 = pd.read_csv("mostchangedpop19-20.csv")
B_pop1819 = pd.read_csv("leastchangedpop18-19.csv")
B_pop1920 = pd.read_csv("leastchangedpop19-20.csv")
T_house = pd.read_csv("top10inventory.csv")
B_house = pd.read_csv("bottom10inventory.csv")
T_rental = pd.read_csv("top10rental.csv")
B_rental = pd.read_csv("bottom10rental.csv")

#data set with changing rates
population_df = pd.read_csv("sorted_population.csv")
rental_df = pd.read_csv("rental_rate.csv")
housing_df = pd.read_csv("housing_rate.csv")
All_df =pd.read_csv("ChangingRates.csv")

# %%
popTR1819 = T_pop1819["2018-2019 Population Rate"]
x_axis = np.arange(T_pop1819["City"].nunique())
plt.bar(x_axis, popTR1819)
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(T_pop1819["City"]), rotation='vertical')
plt.title("Cities with the Highest Increased Population Rate 2018-2019")
plt.xlabel("City")
plt.ylabel("Population")
plt.show()

# %%
popTR1920 = T_pop1920["2019-2020 Population Rate"]
x_axis = np.arange(T_pop1920["City"].nunique())
plt.bar(x_axis, popTR1920, color="green")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(T_pop1920["City"]), rotation='vertical')
plt.title("Cities with the Highest Increased Population Rate 2019-2020")
plt.xlabel("City")
plt.ylabel("Population")
plt.show()

# %%
popBR1819 = B_pop1819["2018-2019 Population Rate"]
x_axis = np.arange(B_pop1819["City"].nunique())
plt.bar(x_axis, popBR1819, color="pink")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(B_pop1819["City"]), rotation='vertical')
plt.title("Cities with the Lowest Increased Population Rate 2018-2019")
plt.xlabel("City")
plt.ylabel("Population")
plt.show()

# %%
popBR1920 = B_pop1920["2019-2020 Population Rate"]
x_axis = np.arange(B_pop1920["City"].nunique())
plt.bar(x_axis, popBR1920, color="orange")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(B_pop1920["City"]), rotation='vertical')
plt.title("Cities with the Lowest Increased Population Rate 2019-2020")
plt.xlabel("City")
plt.ylabel("Population")
plt.show()

# %%
T_pop1819["City"]=T_pop1819["City"]+", "+T_pop1819["State"]
T_pop1920["City"]=T_pop1920["City"]+", "+T_pop1920["State"]

popsummary_df = T_pop1819[["City"]]
popsummary_df["2018-2019 Rate"] = T_pop1819["2018-2019 Population Rate"]
popsummary_df["Top20 Cities 2019-2020"] = T_pop1920["City"]
popsummary_df["2019-2020 Rate"] = T_pop1920["2019-2020 Population Rate"]
popsummary_df=popsummary_df.rename(columns={"City" : "Top20 Cities 2018-2019"})

popsummary_df
# Out:
# <ipython-input-7-f66eabb0b31a>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popsummary_df["2018-2019 Rate"] = T_pop1819["2018-2019 Population Rate"]
# <ipython-input-7-f66eabb0b31a>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popsummary_df["Top20 Cities 2019-2020"] = T_pop1920["City"]
# <ipython-input-7-f66eabb0b31a>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popsummary_df["2019-2020 Rate"] = T_pop1920["2019-2020 Population Rate"]
#    Top20 Cities 2018-2019  2018-2019 Rate Top20 Cities 2019-2020  \
# 0             Frisco , TX        6.387834            Frisco , TX
# 1           McKinney , TX        3.874356    Salt Lake City , UT
# 2       Murfreesboro , TN        3.858826            Irvine , CA
# 3     Port St. Lucie , FL        3.612788          McKinney , TX
# 4          Henderson , NV        3.447619          Bellevue , WA
# 5           Surprise , AZ        2.866022           Hialeah , FL
# 6            Midland , TX        2.718519       Clarksville , TN
# 7    North Las Vegas , NV        2.700235        Alexandria , VA
# 8         Cape Coral , FL        2.653218             Miami , FL
# 9            Ontario , CA        2.374971           Seattle , WA
# 10            Denton , TX        2.332357       Sioux Falls , SD
# 11              Reno , NV        2.180726             Tampa , FL
# 12            Peoria , AZ        2.146718       Jersey City , NJ
# 13             Tempe , AZ        2.116863              Waco , TX
# 14            Irvine , CA        2.012196           Atlanta , GA
# 15           Killeen , TX        2.006282            Eugene , OR
# 16     Moreno Valley , CA        1.994361             Salem , OR
# 17              Mesa , AZ        1.981907         Henderson , NV
# 18       Sioux Falls , SD        1.881950            Dallas , TX
# 19         Roseville , CA        1.832994          Chandler , AZ
# 20        Fort Worth , TX        1.832591      Murfreesboro , TN
#
#     2019-2020 Rate
# 0         7.267195
# 1         6.381907
# 2         5.760244
# 3         4.674234
# 4         4.375557
# 5         4.229469
# 6         4.015277
# 7         3.964172
# 8         3.937277
# 9         3.909112
# 10        3.659552
# 11        3.503628
# 12        3.443289
# 13        3.432302
# 14        3.339904
# 15        3.306068
# 16        3.199610
# 17        3.090362
# 18        2.880156
# 19        2.875577
# 20        2.835943

# %%
B_pop1819["City"]=B_pop1819["City"]+", "+B_pop1819["State"]
B_pop1920["City"]=B_pop1920["City"]+", "+B_pop1920["State"]

poplow_df = B_pop1819[["City"]]
poplow_df["2018-2019 Rate"] = B_pop1819["2018-2019 Population Rate"]
poplow_df["Bottom 20 Cities 2019-2020"] = B_pop1920["City"]
poplow_df["2019-2020 Rate"] = B_pop1920["2019-2020 Population Rate"]
poplow_df=poplow_df.rename(columns={"City" : "Bottom 20 Cities 2018-2019"})

poplow_df
# Out:
# <ipython-input-8-a4ff9f169ebd>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poplow_df["2018-2019 Rate"] = B_pop1819["2018-2019 Population Rate"]
# <ipython-input-8-a4ff9f169ebd>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poplow_df["Bottom 20 Cities 2019-2020"] = B_pop1920["City"]
# <ipython-input-8-a4ff9f169ebd>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poplow_df["2019-2020 Rate"] = B_pop1920["2019-2020 Population Rate"]
#    Bottom 20 Cities 2018-2019  2018-2019 Rate Bottom 20 Cities 2019-2020  \
# 0                Jackson , MS       -1.919742              Columbus , GA
# 1              Baltimore , MD       -1.486116          Fayetteville , NC
# 2             Shreveport , LA       -1.187157             St. Louis , MO
# 3               Pasadena , TX       -0.986034            Pittsburgh , PA
# 4              St. Louis , MO       -0.936988            Shreveport , LA
# 5               Savannah , GA       -0.927875           Baton Rouge , LA
# 6            Baton Rouge , LA       -0.879428                 Omaha , NE
# 7             Des Moines , IA       -0.813449          Newport News , VA
# 8               Torrance , CA       -0.769837          Indianapolis , IN
# 9                 Toledo , OH       -0.758557                 Tulsa , OK
# 10               Garland , TX       -0.736836         Santa Clarita , CA
# 11                Aurora , IL       -0.723899                Mobile , AL
# 12            Long Beach , CA       -0.694836            Bridgeport , CT
# 13              Palmdale , CA       -0.690967             Rochester , NY
# 14              Glendale , CA       -0.690126                 Tempe , AZ
# 15               Hialeah , FL       -0.681873                Toledo , OH
# 16                Irving , TX       -0.673504             Milwaukee , WI
# 17           Jersey City , NJ       -0.673107          Garden Grove , CA
# 18             Lancaster , CA       -0.643669               Midland , TX
# 19              New York , NY       -0.634845               Yonkers , NY
# 20              San Jose , CA       -0.605533               Fremont , CA
#
#     2019-2020 Rate
# 0        -3.306448
# 1        -2.839972
# 2        -2.257000
# 3        -1.806944
# 4        -1.759909
# 5        -1.605096
# 6        -1.566316
# 7        -1.205747
# 8        -1.161224
# 9        -1.158304
# 10       -1.143775
# 11       -1.015261
# 12       -0.961918
# 13       -0.925156
# 14       -0.810500
# 15       -0.780119
# 16       -0.774031
# 17       -0.766703
# 18       -0.702557
# 19       -0.673254
# 20       -0.657376
