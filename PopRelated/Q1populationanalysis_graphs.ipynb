# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import scipy.stats as st
import matplotlib.patches as mpatches

# Suppress warnings
import warnings
warnings.filterwarnings("ignore")

# %%
#reading csvs from cleaned data set
cleaned_pop_df = pd.read_csv("../CleanedData/cleaned_population.csv")

#top&bottom csvs
T_pop1819 = pd.read_csv("../TopBottom/mostchangedpop18-19.csv")
T_pop1920 = pd.read_csv("../TopBottom/mostchangedpop19-20.csv")
B_pop1819 = pd.read_csv("../TopBottom/leastchangedpop18-19.csv")
B_pop1920 = pd.read_csv("../TopBottom/leastchangedpop19-20.csv")

max_rate_change = pd.read_csv("../TopBottom/mostratechange18-20.csv")
least_rate_change = pd.read_csv("../TopBottom/leastratechange18-20.csv")


#data set with changing rates
population_df = pd.read_csv("sorted_population_final.csv")
All_df =pd.read_csv("../QuestionsAnalysis/ChangingRates.csv")

# %%
#plotting bar graph for the population changing rates of top20 cities 2018-2019
popTR1819 = T_pop1819["2018-2019 Population Rate"]
x_axis = np.arange(T_pop1819["City"].nunique())
plt.bar(x_axis, popTR1819)
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(T_pop1819["City"]), rotation='vertical')
plt.title("Cities with the Highest Population Rate Increase in 2018-2019")
plt.xlabel("City")
plt.ylabel("Population Rate Increases (%)")
plt.tight_layout()
plt.savefig('../Output/Cities with the Highest Population Rate Increase in 2018-2019.png')
plt.show()

# %%
#plotting horizontal bar graph for the population changing rate of top20 cities  2018-2019 
popTR1819 = T_pop1819["2018-2019 Population Rate"]
x_axis = np.arange(T_pop1819["City"].nunique())
plt.barh(x_axis, popTR1819)
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(T_pop1819["City"]), rotation='horizontal')
plt.title("Cities with the Highest Population Rate Increase in 2018-2019")
plt.xlabel("Population Rate Increases (%)")
plt.tight_layout()
plt.savefig('../Output/Cities with the Highest Population Rate Increase in 2018-2019 H.png')
plt.show()

# %%
#plotting bar graph for the population changing rate of top20 cities 2019-2020
popTR1920 = T_pop1920["2019-2020 Population Rate"]
x_axis = np.arange(T_pop1920["City"].nunique())
plt.bar(x_axis, popTR1920,color="green")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(T_pop1920["City"]), rotation='vertical')
plt.title("Cities with the Highest Population Rate Increase in 2019-2020")
plt.xlabel("City")
plt.ylabel("Population Rate Increases (%)")
plt.tight_layout()
plt.savefig('../Output/Cities with the Highest Population Rate Increase in 2019-2020.png')
plt.show()

# %%
#plotting horizontal bar graph for the population changing rate of top20 cities 2019-2020
popTR1920 = T_pop1920["2019-2020 Population Rate"]
x_axis = np.arange(T_pop1920["City"].nunique())
plt.barh(x_axis, popTR1920,color="green")
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(T_pop1920["City"]), rotation='horizontal')
plt.title("Cities with the Highest Population Rate Increase in 2019-2020")
plt.xlabel("Population Rate Increases (%)")
plt.tight_layout()
plt.savefig('../Output/Cities with the Highest Population Rate Increase in 2019-2020H.png')
plt.show()

# %%
#plotting bar graph for the population changing rates of bottom 20 cities 2018-2019
popBR1819 = B_pop1819["2018-2019 Population Rate"]
x_axis = np.arange(B_pop1819["City"].nunique())
plt.bar(x_axis, popBR1819, color="pink")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(B_pop1819["City"]), rotation='vertical')
plt.title("Cities with the Largest Decrease in Population Rate in 2018-2019")
plt.xlabel("City")
plt.ylabel("Population Rate Increases (%)")
plt.tight_layout()
plt.savefig('../Output/Cities with the Largest Decrease in Population Rate in 2018-2019.png')
plt.show()

# %%
#plotting horizontal bar graph for the population changing rates of bottom 20 cities 2019-2020
popBR1819 = B_pop1819["2018-2019 Population Rate"]
x_axis = np.arange(B_pop1819["City"].nunique())
plt.barh(x_axis, popBR1819, color="pink")
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(B_pop1819["City"]), rotation='horizontal')
plt.title("Cities with the Largest Decrease in Population Rate in 2018-2019")
plt.xlabel("Population Rate Increases (%)")
plt.tight_layout()
plt.savefig('../Output/Cities with the Largest Decrease in Population Rate in 2018-2019H.png')
plt.show()

# %%
#plotting bar graph for the population changing rates of bottom 20 cities 2019-2020
popBR1920 = B_pop1920["2019-2020 Population Rate"]
x_axis = np.arange(B_pop1920["City"].nunique())
plt.bar(x_axis, popBR1920, color="orange")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(B_pop1920["City"]), rotation='vertical')
plt.title("Cities with the Largest Decrease in Population Rate 2019-2020")
plt.xlabel("City")
plt.ylabel("Population Rate Increases (%)")
plt.tight_layout()

plt.savefig('../Output/Cities with the Largest Decrease in Population Rate in 2019-2020.png')
plt.show()

# %%
#plotting horizontal bar graph for the population changing rates of bottom 20 cities 2019-2020
popBR1920 = B_pop1920["2019-2020 Population Rate"]
x_axis = np.arange(B_pop1920["City"].nunique())
plt.barh(x_axis, popBR1920, color="orange")
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(B_pop1920["City"]), rotation='horizontal')
plt.title("Cities with the Largest Decrease in Population Rate 2019-2020")
plt.xlabel("Population Rate Increases (%)")
plt.tight_layout()

plt.savefig('../Output/Cities with the Largest Decrease in Population Rate in 2019-2020H.png')
plt.show()

# %%
#plotting bar graph for the overall population changing rates of top 20 cities 2018-2020
pop1 = max_rate_change["Diff in Pop Rate 2018-2020"]
x_axis = np.arange(max_rate_change["City"].nunique())
plt.bar(x_axis, pop1, color="skyblue")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(max_rate_change["City"]), rotation='vertical')
plt.title("Cities with the Largest Change in Population Rate 2018-2020")
plt.xlabel("City")
plt.ylabel("Population Rate Changes (%)")
plt.tight_layout()
plt.savefig('../Output/Cities with Highest Demand Seen in Population Growth Rate 2018-2020.png')
plt.show()

#Are people moving into these cities?

# %%
#plotting bar graph for the overall population changing rates of bottom 20 cities 2018-2020
pop2 = least_rate_change["Diff in Pop Rate 2018-2020"]
x_axis = np.arange(least_rate_change["City"].nunique())
plt.bar(x_axis,pop2, color="lightpink")
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, list(least_rate_change["City"]), rotation='vertical')
plt.title("Cities with the Most Decrease in Population Rate 2018-2020")
plt.xlabel("City")
plt.ylabel("Population Rate Changes (%)")
plt.tight_layout()
plt.savefig('../Output/Cities with Lowest Demand Seen in Population Loss Rate 2018-2020.png')
plt.show()

# %%
#plotting bar graph for the overall population changing rates of top and bottom 20 cities 2018-2020
df1 = least_rate_change[["City","Diff in Pop Rate 2018-2020"]]
df1=df1.rename(columns = {"Diff in Pop Rate 2018-2020":"Rate"})

df2 = max_rate_change[["City","Diff in Pop Rate 2018-2020"]]
df2=df2.rename(columns = {"Diff in Pop Rate 2018-2020":"Rate"})
frames = [df1, df2]
result=pd.concat(frames)

# %matplotlib notebook
result.plot(kind="barh")
plt.title("Cities with Change in Population Rate 2018-2020")
plt.xlabel("Population Growth Rate Changes (%)")
plt.yticks(tick_locations, list(result["City"]), rotation='horizontal')
plt.savefig('../Output/Cities with the Most Decrease in Population Rate 2018-2020H.png')
plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
#Top 20 cities with the highest changing rate 2018-2019 and 2019-2020
T_pop1819["City"]=T_pop1819["City"]+", "+T_pop1819["State"]
T_pop1920["City"]=T_pop1920["City"]+", "+T_pop1920["State"]

popsummary_df = T_pop1819[["City"]]
popsummary_df["2018-2019 Rate"] = T_pop1819["2018-2019 Population Rate"]
popsummary_df["Top 20 Cities 2019-2020"] = T_pop1920["City"]
popsummary_df["2019-2020 Rate"] = T_pop1920["2019-2020 Population Rate"]
popsummary_df=popsummary_df.rename(columns={"City" : "Top 20 Cities 2018-2019"})

popsummary_df
# Out:
#    Top 20 Cities 2018-2019  2018-2019 Rate Top 20 Cities 2019-2020  \
# 0              Frisco , TX        6.387834             Frisco , TX
# 1            McKinney , TX        3.874356     Salt Lake City , UT
# 2        Murfreesboro , TN        3.858826             Irvine , CA
# 3      Port St. Lucie , FL        3.612788           McKinney , TX
# 4           Henderson , NV        3.447619           Bellevue , WA
# 5            Surprise , AZ        2.866022            Hialeah , FL
# 6             Midland , TX        2.718519        Clarksville , TN
# 7     North Las Vegas , NV        2.700235         Alexandria , VA
# 8          Cape Coral , FL        2.653218              Miami , FL
# 9             Ontario , CA        2.374971            Seattle , WA
# 10             Denton , TX        2.332357        Sioux Falls , SD
# 11               Reno , NV        2.180726              Tampa , FL
# 12             Peoria , AZ        2.146718        Jersey City , NJ
# ...

# %%
#Bottom 20 cities with the highest changing rate 2018-2019 and 2019-2020
B_pop1819["City"]=B_pop1819["City"]+", "+B_pop1819["State"]
B_pop1920["City"]=B_pop1920["City"]+", "+B_pop1920["State"]

poplow_df = B_pop1819[["City"]]
poplow_df["2018-2019 Rate"] = B_pop1819["2018-2019 Population Rate"]
poplow_df["Bottom 20 Cities 2019-2020"] = B_pop1920["City"]
poplow_df["2019-2020 Rate"] = B_pop1920["2019-2020 Population Rate"]
poplow_df=poplow_df.rename(columns={"City" : "Bottom 20 Cities 2018-2019"})

poplow_df
# Out:
#    Bottom 20 Cities 2018-2019  2018-2019 Rate Bottom 20 Cities 2019-2020  \
# 0                Jackson , MS       -1.919742              Columbus , GA
# 1              Baltimore , MD       -1.486116          Fayetteville , NC
# 2             Shreveport , LA       -1.187157             St. Louis , MO
# 3               Pasadena , TX       -0.986034            Pittsburgh , PA
# 4              St. Louis , MO       -0.936988            Shreveport , LA
# 5               Savannah , GA       -0.927875           Baton Rouge , LA
# 6            Baton Rouge , LA       -0.879428                 Omaha , NE
# 7             Des Moines , IA       -0.813449          Newport News , VA
# 8               Torrance , CA       -0.769837          Indianapolis , IN
# 9                 Toledo , OH       -0.758557                 Tulsa , OK
# 10               Garland , TX       -0.736836         Santa Clarita , CA
# 11                Aurora , IL       -0.723899                Mobile , AL
# ...

# %%
# Concatenating city and state for plotting
T_pop1819['City, State']= ''
city_state = T_pop1819['City'].map(str)+', ' + T_pop1819['State'].map(str)
T_pop1819['City, State'] = city_state
T_pop1920['City, State']= ''
city_state = T_pop1920['City'].map(str)+', ' + T_pop1920['State'].map(str)
T_pop1920['City, State'] = city_state
B_pop1819['City, State']= ''
city_state = B_pop1819['City'].map(str)+', ' + B_pop1819['State'].map(str)
B_pop1819['City, State'] = city_state
B_pop1920['City, State']= ''
city_state = B_pop1920['City'].map(str)+', ' + B_pop1920['State'].map(str)

B_pop1920['City, State'] = city_state
max_rate_change['City, State']= ''
city_state = max_rate_change['City'].map(str)+', ' + max_rate_change['State'].map(str)
max_rate_change['City, State'] = city_state
least_rate_change['City, State']= ''
city_state = least_rate_change['City'].map(str)+', ' + least_rate_change['State'].map(str)
least_rate_change['City, State'] = city_state

# %%
#Sort so that largest appears first
T_pop1819 = T_pop1819.sort_values(['2018-2019 Population Rate'])
T_pop1920 = T_pop1920.sort_values(['2019-2020 Population Rate'])
B_pop1819 = B_pop1819.sort_values(['2018-2019 Population Rate'])
B_pop1920 = B_pop1920.sort_values(['2019-2020 Population Rate'])

# %%
#Bar graph of top 20 cities
# %matplotlib notebook
fig, ax=plt.subplots(1)
popTR1819 = T_pop1819["2018-2019 Population Rate"]
x_axis = np.arange(T_pop1819["City, State"].nunique())
plt.barh(x_axis, popTR1819)
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(T_pop1819["City, State"]), rotation='horizontal')
plt.title("Cities with the Largest Population Increase \n (2018-2019)")
plt.xlabel("Population Rate Increase (%)")
plt.tight_layout()
plt.savefig('../Output/Q1Population Increase in 2018-2019.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# %matplotlib notebook
fig, ax=plt.subplots(1)
popTR1920 = T_pop1920["2019-2020 Population Rate"]
x_axis = np.arange(T_pop1920["City, State"].nunique())
plt.barh(x_axis, popTR1920,color="green")
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(T_pop1920["City, State"]), rotation='horizontal')
plt.title("Cities with the Largest Population Rate Increase \n (2019-2020)")
plt.xlabel("Population Rate Increases (%)")
plt.tight_layout()
plt.savefig('../Output/Q1Population Rate Increase in 2019-2020.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# %matplotlib notebook
fig, ax=plt.subplots(1)
popBR1819 = B_pop1819["2018-2019 Population Rate"]
x_axis = np.arange(B_pop1819["City, State"].nunique())
plt.barh(x_axis, popBR1819)
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(B_pop1819["City, State"]),rotation='horizontal')
plt.title("Cities with the Largest Population Rate Decrease\n (2018-2019)")
plt.xlabel("Population Rate Decrease (%)")
plt.tight_layout()
plt.savefig('../Output/Q1Population Rate Decrease in 2018-2019.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
# %matplotlib notebook
fig, ax=plt.subplots(1)
popBR1920 = B_pop1920["2019-2020 Population Rate"]
x_axis = np.arange(B_pop1920["City, State"].nunique())
plt.barh(x_axis, popBR1920, color="green")
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(B_pop1920["City, State"]), rotation='horizontal')
plt.title("Cities with the Largest Population Rate Decrease\n (2019-2020)")
plt.xlabel("Population Rate Decrease (%)")
plt.tight_layout()
plt.savefig('../Output/Q1Population Rate Decrease in 2019-2020.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
fig, ax=plt.subplots(1)
max_rate_change = max_rate_change.sort_values(['Diff in Pop Rate 2018-2020'])
barWidth=0.6
pop1 = max_rate_change["Diff in Pop Rate 2018-2020"]
x_axis = np.arange(max_rate_change["City, State"].nunique())
diff = plt.barh(x_axis, pop1, color="red",height=barWidth)
diff[7].set_color('skyblue')
diff[0].set_color('skyblue')
diff[3].set_color('skyblue')
diff[4].set_color('skyblue')
diff[13].set_color('skyblue')
diff[12].set_color('skyblue')
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(max_rate_change["City, State"]), rotation='horizontal')
plt.title("Cities with the Most Increase in Population Rates\n (2018-2020)")
plt.xlabel("Difference in Population Rate from 2018-2020")
red_patch = mpatches.Patch(color='red', label='Cities Previously in \nTop Population Rate Changes')
skyblue_patch = mpatches.Patch(color='skyblue', label='Cities New to Top Population \n Rate Changes')
plt.legend(handles=[red_patch,skyblue_patch], loc =4)
plt.tight_layout()
plt.savefig('../Output/Q1Highest Demand Cities 2018-2020.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
fig, ax=plt.subplots(1)
barWidth=0.6
pop2 = least_rate_change["Diff in Pop Rate 2018-2020"]
x_axis = np.arange(least_rate_change["City, State"].nunique())
diff = plt.barh(x_axis,pop2, color="blue", height=barWidth)
diff[18].set_color('lightpink')
diff[17].set_color('lightpink')
diff[4].set_color('lightpink')
diff[5].set_color('lightpink')
diff[6].set_color('lightpink')
diff[7].set_color('lightpink')
diff[8].set_color('lightpink')
diff[15].set_color('lightpink')
diff[13].set_color('lightpink')
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(least_rate_change["City, State"]), rotation='horizontal')
plt.title("Cities with the Most Decrease in Population Rate \n(2018-2020)")
plt.xlabel("Difference in Population Rate from 2018-2020")
blue_patch = mpatches.Patch(color='blue', label='Cities Previously in \nBottom Population Rate Changes')
lightpink_patch = mpatches.Patch(color='lightpink', label='Cities New to Bottom Population \nRate Changes')
plt.legend(handles=[blue_patch,lightpink_patch])
plt.tight_layout()
plt.savefig('../Output/Q1Lowest Demand Cities 2018-2020.png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
