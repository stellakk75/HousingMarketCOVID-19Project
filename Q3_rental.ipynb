# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts

# %%
#reading csvs from cleaned data set
cleaned_rental_df = pd.read_csv("cleaned_rental.csv")

# %%
del cleaned_rental_df["Unnamed: 0"]
cleaned_rental_df.head()
# Out:
#            City State  2018-01  2018-02  2018-03  2018-04  2018-05  2018-06  \
# 0      New York    NY   2598.0   2601.0   2605.0   2608.0   2612.0   2617.0
# 1   Los Angeles    CA   2380.0   2388.0   2397.0   2405.0   2414.0   2423.0
# 2       Chicago    IL   1705.0   1708.0   1710.0   1713.0   1716.0   1719.0
# 3        Dallas    TX   1470.0   1474.0   1478.0   1481.0   1485.0   1489.0
# 4  Philadelphia    PA   1505.0   1509.0   1512.0   1516.0   1521.0   1525.0
#
#    2018-07  2018-08  ...  2019-12  2020-01  2020-02  2020-03  2020-04  \
# 0   2621.0   2626.0  ...   2698.0   2694.0   2686.0   2678.0   2671.0
# 1   2432.0   2440.0  ...   2542.0   2544.0   2545.0   2545.0   2546.0
# 2   1722.0   1725.0  ...   1778.0   1778.0   1777.0   1776.0   1776.0
# 3   1493.0   1498.0  ...   1560.0   1562.0   1563.0   1564.0   1566.0
# 4   1530.0   1534.0  ...   1598.0   1600.0   1602.0   1604.0   1606.0
#
#    2020-05  2020-06  2020-07  2020-08  2020-09
# 0   2662.0   2653.0   2644.0   2635.0   2625.0
# 1   2546.0   2546.0   2546.0   2545.0   2545.0
# 2   1775.0   1774.0   1772.0   1771.0   1770.0
# 3   1567.0   1568.0   1570.0   1571.0   1572.0
# 4   1608.0   1610.0   1612.0   1614.0   1615.0
#
# [5 rows x 35 columns]

# %%
#finding the picked cities from the dataframe
df1 = cleaned_rental_df.loc[rental_df["City"]=='Boston']
df2 = cleaned_rental_df.loc[rental_df["City"]=="Salt Lake City"]
df3 = cleaned_rental_df.loc[rental_df["City"]=="Minneapolis"]
df4 = cleaned_rental_df.loc[rental_df["City"]=="Seattle"]
df5 = cleaned_rental_df.loc[rental_df["City"]=="Atlanta"]
df6 = cleaned_rental_df.loc[rental_df["City"]=="Louisville"]
df7 = cleaned_rental_df.loc[rental_df["City"]=="San Jose"]
df8 = cleaned_rental_df.loc[rental_df["City"]=="New York"]
df9 = cleaned_rental_df.loc[rental_df["City"]=="Oklahoma City"]
df10 = cleaned_rental_df.loc[rental_df["City"]=="Denver"]
df11 = cleaned_rental_df.loc[rental_df["City"]=="Kansas City"]

# %%
#combining the found data into a dateframe
frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11]
result_df = pd.concat(frames).reset_index(drop=True)

# %%
#selecting house price data from 2018 to 2020 for each city
Boston = result_df.iloc[0, 2:34]
Salt_Lake_City = result_df.iloc[1, 2:]
Minneapolis = result_df.iloc[2, 2:]
Seattle = result_df.iloc[3, 2:]
Atlanta = result_df.iloc[4, 2:]
Louisville = result_df.iloc[5, 2:]
SanJose = result_df.iloc[6, 2:]
NewYork = result_df.iloc[7, 2:]
OklahomaCity = result_df.iloc[8, 2:]
Denver = result_df.iloc[9, 2:]
KansasCity = result_df.iloc[10, 2:]

# %%
#plotting the house price of each city from 2018 to 2020
# %matplotlib notebook
plt.plot(Boston, label="Boston")
plt.plot(Salt_Lake_City, label="Salt Lake City")
plt.plot(Minneapolis, label="Minneapolis")
plt.plot(Seattle, label="Seattle")
plt.plot(Atlanta, label="Atlanta")
plt.plot(Louisville, label="Louisville")
plt.plot(SanJose, label="SanJose")
plt.plot(NewYork, label="New York")
plt.plot(OklahomaCity, label="Oklahoma City")
plt.plot(Denver, label="Denver")
plt.plot(KansasCity, label="KansasCity")

plt.title("Rental Prices in Cities from 2018 to 2020")
plt.xlabel("Months")
plt.ylabel("Rental Price")
plt.xticks(rotation = 'vertical')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
result_df.columns
# Out:
# Index(['City', 'State', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05',
#        '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11',
#        '2018-12', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05',
#        '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11',
#        '2019-12', '2020-01', '2020-02', '2020-03', '2020-04', '2020-05',
#        '2020-06', '2020-07', '2020-08', '2020-09'],
#       dtype='object')

# %%
#calcuating yearl average of house price of each city
R2018 = ['City', 'State', '2018-01', '2018-02', '2018-03', '2018-04', '2018-05',
       '2018-06', '2018-07', '2018-08', '2018-09', '2018-10', '2018-11',
       '2018-12']
R2018 = result_df[R2018]
R2018["2018 Average"]=R2018.mean(axis=1)

R2019 = ['City', 'State', '2019-01', '2019-02', '2019-03', '2019-04', '2019-05',
       '2019-06', '2019-07', '2019-08', '2019-09', '2019-10', '2019-11','2019-12']
R2019 = result_df[R2019]
R2019["2019 Average"]=R2019.mean(axis=1)

R2020 = ['City', 'State','2020-01', '2020-02', '2020-03', '2020-04', '2020-05',
       '2020-06', '2020-07', '2020-08', '2020-09']
R2020 = result_df[R2020]
R2020["2020 Average"]=R2020.mean(axis=1)

#making dataframe
Ravg_df = R2018[['City', 'State']]
Ravg_df["2018 Average"] = R2018["2018 Average"]
Ravg_df["2019 Average"] = R2019["2019 Average"]
Ravg_df["2020 Average"] = R2020["2020 Average"]
Ravg_df.head()
# Out:
# <ipython-input-53-db2a0874a95d>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R2018["2018 Average"]=R2018.mean(axis=1)
# <ipython-input-53-db2a0874a95d>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R2019["2019 Average"]=R2019.mean(axis=1)
# <ipython-input-53-db2a0874a95d>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   R2020["2020 Average"]=R2020.mean(axis=1)
# <ipython-input-53-db2a0874a95d>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ravg_df["2018 Average"] = R2018["2018 Average"]
# <ipython-input-53-db2a0874a95d>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ravg_df["2019 Average"] = R2019["2019 Average"]
# <ipython-input-53-db2a0874a95d>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Ravg_df["2020 Average"] = R2020["2020 Average"]
#              City State  2018 Average  2019 Average  2020 Average
# 0          Boston    MA   2458.250000   2534.083333   2541.111111
# 1  Salt Lake City    UT   1314.000000   1370.666667   1399.666667
# 2     Minneapolis    MN   1497.583333   1555.583333   1587.444444
# 3         Seattle    WA   1838.000000   1917.250000   1960.777778
# 4         Atlanta    GA   1443.500000   1520.583333   1567.666667

# %%
#calculating yearly changing rate for each city

Rrating_df = R2018[['City', 'State']]
Rrating_df["Changing Rate 2018-2019"] = ((Ravg_df["2019 Average"]- Ravg_df["2018 Average"])/Ravg_df["2019 Average"])*100
Rrating_df["Changing Rate 2019-2020"] = ((Ravg_df["2020 Average"]- Ravg_df["2019 Average"])/Ravg_df["2020 Average"])*100
Rrating_df
# Out:
# <ipython-input-54-ccedaebe9747>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Rrating_df["Changing Rate 2018-2019"] = ((Ravg_df["2019 Average"]- Ravg_df["2018 Average"])/Ravg_df["2019 Average"])*100
# <ipython-input-54-ccedaebe9747>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Rrating_df["Changing Rate 2019-2020"] = ((Ravg_df["2020 Average"]- Ravg_df["2019 Average"])/Ravg_df["2020 Average"])*100
#               City State  Changing Rate 2018-2019  Changing Rate 2019-2020
# 0           Boston    MA                 2.992535                 0.276563
# 1   Salt Lake City    UT                 4.134241                 2.071922
# 2      Minneapolis    MN                 3.728505                 2.007069
# 3          Seattle    WA                 4.133525                 2.219924
# 4          Atlanta    GA                 5.069326                 3.003402
# 5       Louisville    KY                 2.780352                 2.681207
# 6         San Jose    CA                 2.955029                -0.667377
# 7         New York    NY                 2.314455                -0.809045
# 8    Oklahoma City    OK                 3.131673                 1.559581
# 9           Denver    CO                 3.526496                 1.192868
# 10     Kansas City    MO                 2.958199                 3.402816

# %%
ax = Rrating_df.plot.barh(color=["green","orange"], rot=0)
ax.set_title("Changing Rate in Rental Price")
ax.set_xlabel("City")
ax.set_ylabel("Changing Rate in Rental Price")
x_axis = np.arange(Rrating_df["City"].nunique())
tick_locations = [value for value in x_axis]
plt.yticks(tick_locations, list(Rrating_df["City"]), rotation='horizontal')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
