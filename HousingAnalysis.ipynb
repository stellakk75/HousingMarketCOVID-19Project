# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import os

# %%
#read csv file 
housing_df = pd.read_csv("cleaned_inventory.csv")

# %%
housing_df.columns
# Out:
# Index(['Unnamed: 0', 'City', '2018-02-28', '2018-03-31', '2018-04-30',
#        '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30',
#        '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31', '2019-02-28',
#        '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31',
#        '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31',
#        '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31',
#        '2020-06-30', '2020-07-31', '2020-08-31'],
#       dtype='object')

# %%
#January 2018 not included in data 
columns_pull = ['City', '2018-02-28', '2018-03-31', '2018-04-30',
       '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30',
       '2018-10-31', '2018-11-30', '2018-12-31']
housing_2018 = housing_df[columns_pull]

housing_2018
# Out:
#               City  2018-02-28  2018-03-31  2018-04-30  2018-05-31  \
# 0    United States    238000.0    243000.0    245000.0    249500.0
# 1         New York    399840.0    395000.0    400000.0    414782.0
# 2      Los Angeles    625000.0    630000.0    635000.0    650000.0
# 3          Chicago    217500.0    230000.0    239000.0    240000.0
# 4           Dallas    255000.0    265000.0    265000.0    275000.0
# ..             ...         ...         ...         ...         ...
# 116      Faribault    218500.0    194900.0    220000.0    202750.0
# 117      Albemarle    135000.0    143000.0    155000.0    143250.0
# 118      Kerrville    215000.0    235000.0    253125.0    250000.0
# 119    Shelbyville    160000.0    155500.0    160000.0    166800.0
# 120     Wilmington    115500.0    152250.0    135000.0    123150.0
#
#      2018-06-30  2018-07-31  2018-08-31  2018-09-30  2018-10-31  2018-11-30  \
# 0      255000.0    250000.0    249900.0    245000.0    244000.0    245500.0
# ...

# %%
#12 months included in 2019 
columns_pull = ['City', '2019-01-31', '2019-02-28',
       '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31',
       '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31']
housing_2019 = housing_df[columns_pull]
housing_2019
# Out:
#               City  2019-01-31  2019-02-28  2019-03-31  2019-04-30  \
# 0    United States    243000.0    242500.0    250000.0    253000.0
# 1         New York    410000.0    410000.0    400000.0    410000.0
# 2      Los Angeles    615000.0    629000.0    640000.0    650000.0
# 3          Chicago    216000.0    222000.0    232500.0    240000.0
# 4           Dallas    249900.0    259000.0    267000.0    269093.0
# ..             ...         ...         ...         ...         ...
# 116      Faribault    219450.0    211700.0    229900.0    239500.0
# 117      Albemarle    154000.0    165000.0    165000.0    169950.0
# 118      Kerrville    240500.0    247500.0    242500.0    255750.0
# 119    Shelbyville    160000.0    197200.0    185000.0    179900.0
# 120     Wilmington    120000.0    124000.0    128800.0    135000.0
#
#      2019-05-31  2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  \
# 0      260000.0    265000.0    262500.0    260000.0    256000.0    255500.0
# ...

# %%
columns_pull = ['City', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31',
       '2020-06-30', '2020-07-31', '2020-08-31']
housing_2020 = housing_df[columns_pull]
housing_2020
# Out:
#               City  2020-01-31  2020-02-29  2020-03-31  2020-04-30  \
# 0    United States    254000.0    259900.0    265000.0    267000.0
# 1         New York    423000.0    423750.0    420000.0    435000.0
# 2      Los Angeles    655000.0    658000.0    679000.0    665000.0
# 3          Chicago    223000.0    225000.0    248000.0    260000.0
# 4           Dallas    265000.0    273900.0    280000.0    285000.0
# ..             ...         ...         ...         ...         ...
# 116      Faribault    225450.0    226200.0    255500.0    253750.0
# 117      Albemarle    157000.0    192000.0    168000.0    169000.0
# 118      Kerrville    268000.0    273500.0    278500.0    275079.0
# 119    Shelbyville    187495.0    174950.0    189000.0    189950.0
# 120     Wilmington    139900.0    135450.0    128600.0    138450.0
#
#      2020-05-31  2020-06-30  2020-07-31  2020-08-31
# 0      264820.0    272500.0    284000.0    285500.0
# 1      434950.0    445000.0    448250.0    455000.0
# ...
