# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#read csv file 
housing_df = pd.read_csv("cleaned_inventory.csv")

# %%
housing_df.columns
# Out:
# Index(['Unnamed: 0', 'City', 'State', '2018-01-31', '2018-02-28', '2018-03-31',
#        '2018-04-30', '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31',
#        '2018-09-30', '2018-10-31', '2018-11-30', '2018-12-31', '2019-01-31',
#        '2019-02-28', '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30',
#        '2019-07-31', '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30',
#        '2019-12-31', '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#        '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31'],
#       dtype='object')

# %%
#2018 inventory price data 
columns_pull = ['City', 'State', '2018-01-31','2018-02-28', '2018-03-31', '2018-04-30',
       '2018-05-31', '2018-06-30', '2018-07-31', '2018-08-31', '2018-09-30',
       '2018-10-31', '2018-11-30', '2018-12-31']
housing_2018 = housing_df[columns_pull]

housing_2018
# Out:
#              City State  2018-01-31  2018-02-28  2018-03-31  2018-04-30  \
# 0        New York    NY    400000.0    399840.0    395000.0    400000.0
# 1     Los Angeles    CA    599000.0    625000.0    630000.0    635000.0
# 2         Chicago    IL    215000.0    217500.0    230000.0    239000.0
# 3          Dallas    TX    246000.0    255000.0    265000.0    265000.0
# 4    Philadelphia    PA    220000.0    220000.0    230000.0    235000.0
# ..            ...   ...         ...         ...         ...         ...
# 115     Faribault    MN    218900.0    218500.0    194900.0    220000.0
# 116     Albemarle    NC    128000.0    135000.0    143000.0    155000.0
# 117     Kerrville    TX    255000.0    215000.0    235000.0    253125.0
# 118   Shelbyville    TN    159900.0    160000.0    155500.0    160000.0
# 119    Wilmington    OH    118000.0    115500.0    152250.0    135000.0
#
#      2018-05-31  2018-06-30  2018-07-31  2018-08-31  2018-09-30  2018-10-31  \
# 0      414782.0    425000.0    430000.0    430000.0    420000.0    408147.0
# 1      650000.0    652000.0    645000.0    650000.0    635000.0    635000.0
# 2      240000.0    249900.0    243000.0    233000.0    229000.0    222000.0
# 3      275000.0    280000.0    274000.0    267000.0    260000.0    257000.0
# 4      242000.0    250000.0    252000.0    255000.0    244000.0    232750.0
# ..          ...         ...         ...         ...         ...         ...
# 115    202750.0    221000.0    222318.0    236306.0    225000.0    208676.0
# 116    143250.0    142750.0    139000.0    164000.0    150000.0    151500.0
# 117    250000.0    266000.0    257500.0    223500.0    228000.0    263000.0
# 118    166800.0    164000.0    162500.0    171000.0    194900.0    161000.0
# 119    123150.0    129000.0    137500.0    128300.0    130000.0    126000.0
#
#      2018-11-30  2018-12-31
# 0      410000.0    402000.0
# 1      640000.0    625000.0
# 2      223000.0    220000.0
# 3      258000.0    264900.0
# 4      236700.0    237000.0
# ..          ...         ...
# 115    220000.0    225000.0
# 116    142000.0    155000.0
# 117    256500.0    267500.0
# 118    166500.0    162450.0
# 119    115250.0    126250.0
#
# [120 rows x 14 columns]

# %%
#2019 inventory data
columns_pull = ['City', 'State', '2019-01-31', '2019-02-28',
       '2019-03-31', '2019-04-30', '2019-05-31', '2019-06-30', '2019-07-31',
       '2019-08-31', '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31']
housing_2019 = housing_df[columns_pull]
housing_2019
# Out:
#              City State  2019-01-31  2019-02-28  2019-03-31  2019-04-30  \
# 0        New York    NY    410000.0    410000.0    400000.0    410000.0
# 1     Los Angeles    CA    615000.0    629000.0    640000.0    650000.0
# 2         Chicago    IL    216000.0    222000.0    232500.0    240000.0
# 3          Dallas    TX    249900.0    259000.0    267000.0    269093.0
# 4    Philadelphia    PA    229000.0    225000.0    240000.0    242821.0
# ..            ...   ...         ...         ...         ...         ...
# 115     Faribault    MN    219450.0    211700.0    229900.0    239500.0
# 116     Albemarle    NC    154000.0    165000.0    165000.0    169950.0
# 117     Kerrville    TX    240500.0    247500.0    242500.0    255750.0
# 118   Shelbyville    TN    160000.0    197200.0    185000.0    179900.0
# 119    Wilmington    OH    120000.0    124000.0    128800.0    135000.0
#
#      2019-05-31  2019-06-30  2019-07-31  2019-08-31  2019-09-30  2019-10-31  \
# 0      420000.0    435000.0    440000.0    435000.0    427500.0    424450.0
# 1      645000.0    653500.0    670000.0    650000.0    650000.0    650000.0
# 2      246000.0    249500.0    249000.0    242000.0    235000.0    231000.0
# 3      280000.0    283000.0    277000.0    275000.0    270000.0    270000.0
# 4      251000.0    265000.0    266000.0    262400.0    250000.0    245000.0
# ..          ...         ...         ...         ...         ...         ...
# 115    240000.0    255000.0    245000.0    267000.0    247495.0    240500.0
# 116    170500.0    192500.0    174500.0    184000.0    180000.0    179000.0
# 117    289000.0    267000.0    236250.0    235000.0    232750.0    318500.0
# 118    183500.0    176900.0    187900.0    201000.0    194825.0    193950.0
# 119    158950.0    140000.0    123050.0    135000.0    142500.0    137500.0
#
#      2019-11-30  2019-12-31
# 0      419986.0    420000.0
# 1      650000.0    655000.0
# 2      231250.0    230000.0
# 3      270000.0    275000.0
# 4      250000.0    250000.0
# ..          ...         ...
# 115    237500.0    240000.0
# 116    169500.0    194000.0
# 117    239750.0    256750.0
# 118    191500.0    205000.0
# 119    134000.0    136500.0
#
# [120 rows x 14 columns]

# %%
#2020 inventory data
columns_pull = ['City', 'State','2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31',
       '2020-06-30', '2020-07-31', '2020-08-31']
housing_2020 = housing_df[columns_pull]
housing_2020
# Out:
#              City State  2020-01-31  2020-02-29  2020-03-31  2020-04-30  \
# 0        New York    NY    423000.0    423750.0    420000.0    435000.0
# 1     Los Angeles    CA    655000.0    658000.0    679000.0    665000.0
# 2         Chicago    IL    223000.0    225000.0    248000.0    260000.0
# 3          Dallas    TX    265000.0    273900.0    280000.0    285000.0
# 4    Philadelphia    PA    239550.0    240000.0    250000.0    270000.0
# ..            ...   ...         ...         ...         ...         ...
# 115     Faribault    MN    225450.0    226200.0    255500.0    253750.0
# 116     Albemarle    NC    157000.0    192000.0    168000.0    169000.0
# 117     Kerrville    TX    268000.0    273500.0    278500.0    275079.0
# 118   Shelbyville    TN    187495.0    174950.0    189000.0    189950.0
# 119    Wilmington    OH    139900.0    135450.0    128600.0    138450.0
#
#      2020-05-31  2020-06-30  2020-07-31  2020-08-31
# 0      434950.0    445000.0    448250.0    455000.0
# 1      650000.0    681500.0    710000.0    725000.0
# 2      251000.0    254000.0    262000.0    270000.0
# 3      280000.0    290000.0    300000.0    300000.0
# 4      261250.0    269000.0    278000.0    279900.0
# ..          ...         ...         ...         ...
# 115    265000.0    267983.0    280000.0    264000.0
# 116    175000.0    200000.0    184100.0    183000.0
# 117    304500.0    265650.0    281063.0    298750.0
# 118    209150.0    187000.0    213000.0    198000.0
# 119    138500.0    160000.0    165000.0    159900.0
#
# [120 rows x 10 columns]
