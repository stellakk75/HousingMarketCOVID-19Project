# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import os

# %%
#read csv file 
pop2020_df = pd.read_csv("cleaned_population.csv")

# %%
# loop- go through each row and calculate change in rate from 2018 to 2019 

pop2020_df["2018-2019 Population Rate"] = ''

for row in pop2020_df:
    rate_19 = ((pop2020_df['2019 Population']- pop2020_df['2018 Population'])/pop2020_df['2018 Population'])*100
    pop2020_df['2018-2019 Population Rate'] = rate_19
    
del pop2020_df["Unnamed: 0"]    

sorted_pop = pop2020_df.sort_values(by=['2018-2019 Population Rate'], ascending = False)    
sorted_pop
# Out:
#                 City State  2018 Population  2019 Population 2020 Population  \
# 153          Frisco     TX           188452           200490         215,060
# 162        McKinney     TX           191748           199177         208,487
# 143    Murfreesboro     TN           141442           146900         151,066
# 71   Port St. Lucie     FL           194808           201846         206,410
# 107       Henderson     NV           309518           320189         330,084
# ..               ...   ...              ...              ...             ...
# 103       St. Louis     MO           303419           300576         293,792
# 164        Pasadena     TX           152733           151227         151,891
# 92       Shreveport     LA           189360           187112         183,819
# 93        Baltimore     MD           602443           593490         590,479
# 101         Jackson     MS           163772           160628         160,080
#
#      2018-2019 Population Rate
# 153                   6.387834
# 162                   3.874356
# 143                   3.858826
# 71                    3.612788
# 107                   3.447619
# ..                         ...
# 103                  -0.936988
# 164                  -0.986034
# 92                   -1.187157
# 93                   -1.486116
# 101                  -1.919742
#
# [182 rows x 6 columns]

# %%
#convert 2020 population data type to int
sorted_pop = sorted_pop.replace(',','', regex=True)
sorted_pop['2020 Population'] = pd.to_numeric(sorted_pop['2020 Population'])
sorted_pop.dtypes
# Out:
# City                          object
# State                         object
# 2018 Population                int64
# 2019 Population                int64
# 2020 Population                int64
# 2018-2019 Population Rate    float64
# dtype: object

# %%
# loop- go through each row and calculate change in rate from 2019 to 2020

sorted_pop["2019-2020 Population Rate"] = ''

for row in sorted_pop:
    rate_20 = ((sorted_pop['2020 Population']- sorted_pop['2019 Population'])/sorted_pop['2019 Population'])*100
    sorted_pop['2019-2020 Population Rate'] = rate_20
sorted_pop2 = sorted_pop.sort_values(by=['2019-2020 Population Rate'], ascending = False)
sorted_pop2.to_csv("sorted_population.csv")
sorted_pop2
# Out:
#                 City State  2018 Population  2019 Population  2020 Population  \
# 153          Frisco     TX           188452           200490           215060
# 168  Salt Lake City     UT           200435           200567           213367
# 27           Irvine     CA           281732           287401           303956
# 162        McKinney     TX           191748           199177           208487
# 175        Bellevue     WA           147064           148164           154647
# ..               ...   ...              ...              ...              ...
# 92       Shreveport     LA           189360           187112           183819
# 136      Pittsburgh     PA           300570           300286           294860
# 103       St. Louis     MO           303419           300576           293792
# 121    Fayetteville     NC           210748           211657           205646
# 76         Columbus     GA           194169           195769           189296
#
#      2018-2019 Population Rate  2019-2020 Population Rate
# 153                   6.387834                   7.267195
# 168                   0.065857                   6.381907
# 27                    2.012196                   5.760244
# 162                   3.874356                   4.674234
# 175                   0.747974                   4.375557
# ..                         ...                        ...
# 92                   -1.187157                  -1.759909
# 136                  -0.094487                  -1.806944
# 103                  -0.936988                  -2.257000
# 121                   0.431321                  -2.839972
# 76                    0.824024                  -3.306448
#
# [182 rows x 7 columns]

# %%
#finding the cities with the most drastic population change
top1819 = sorted_pop2.nlargest(21, '2018-2019 Population Rate')
toprate = sorted_pop2.nlargest(21, '2019-2020 Population Rate')
top1819.to_csv("mostchangedpop18-19.csv")
toprate.to_csv("mostchangedpop19-20.csv")
toprate
# Out:
#                 City State  2018 Population  2019 Population  2020 Population  \
# 153          Frisco     TX           188452           200490           215060
# 168  Salt Lake City     UT           200435           200567           213367
# 27           Irvine     CA           281732           287401           303956
# 162        McKinney     TX           191748           199177           208487
# 175        Bellevue     WA           147064           148164           154647
# 64          Hialeah     FL           234941           233339           243208
# 140     Clarksville     TN           156376           158146           164496
# 169      Alexandria     VA           159069           159428           165748
# 67            Miami     FL           462819           467963           486388
# 176         Seattle     WA           742235           753675           783137
# 138     Sioux Falls     SD           180398           183793           190519
# 74            Tampa     FL           397232           399700           413704
# 111     Jersey City     NJ           263851           262075           271099
# 167            Waco     TX           137886           139236           144015
# 75          Atlanta     GA           498183           506811           523738
# 132          Eugene     OR           170701           172622           178329
# 134           Salem     OR           172646           174365           179944
# 107       Henderson     NV           309518           320189           330084
# 149          Dallas     TX          1341802          1343573          1382270
# 4          Chandler     AZ           257186           261165           268675
# 143    Murfreesboro     TN           141442           146900           151066
#
#      2018-2019 Population Rate  2019-2020 Population Rate
# 153                   6.387834                   7.267195
# 168                   0.065857                   6.381907
# 27                    2.012196                   5.760244
# 162                   3.874356                   4.674234
# 175                   0.747974                   4.375557
# 64                   -0.681873                   4.229469
# 140                   1.131887                   4.015277
# 169                   0.225688                   3.964172
# 67                    1.111450                   3.937277
# 176                   1.541291                   3.909112
# 138                   1.881950                   3.659552
# 74                    0.621299                   3.503628
# 111                  -0.673107                   3.443289
# 167                   0.979070                   3.432302
# 75                    1.731894                   3.339904
# 132                   1.125360                   3.306068
# 134                   0.995679                   3.199610
# 107                   3.447619                   3.090362
# 149                   0.131987                   2.880156
# 4                     1.547129                   2.875577
# 143                   3.858826                   2.835943

# %%
#finding the cities with the least drastic population change
bottom1819=sorted_pop2.nsmallest(21, '2018-2019 Population Rate')
bottomrate=sorted_pop2.nsmallest(21, '2019-2020 Population Rate')
bottom1819.to_csv("leastchangedpop18-19.csv")
bottomrate.to_csv("leastchangedpop19-20.csv")
bottomrate
# Out:
#                City State  2018 Population  2019 Population  2020 Population  \
# 76        Columbus     GA           194169           195769           189296
# 121   Fayetteville     NC           210748           211657           205646
# 103      St. Louis     MO           303419           300576           293792
# 136     Pittsburgh     PA           300570           300286           294860
# 92      Shreveport     LA           189360           187112           183819
# 90     Baton Rouge     LA           222190           220236           216701
# 106          Omaha     NE           477299           478192           470702
# 171   Newport News     VA           178523           179225           177064
# 84    Indianapolis     IN           880739           886220           875929
# 131          Tulsa     OK           400414           401190           396543
# 49   Santa Clarita     CA           213549           212979           210543
# 2           Mobile     AL           189809           188720           186804
# 60      Bridgeport     CT           144772           144399           143010
# 117      Rochester     NY           206004           205695           203792
# 11           Tempe     AZ           191746           195805           194218
# 129         Toledo     OH           274864           272779           270651
# 181      Milwaukee     WI           591375           590157           585589
# 23    Garden Grove     CA           172195           171644           170328
# 163        Midland     TX           142173           146038           145012
# 118        Yonkers     NY           199883           200370           199021
# 21         Fremont     CA           237811           241110           239525
#
#      2018-2019 Population Rate  2019-2020 Population Rate
# 76                    0.824024                  -3.306448
# 121                   0.431321                  -2.839972
# 103                  -0.936988                  -2.257000
# 136                  -0.094487                  -1.806944
# 92                   -1.187157                  -1.759909
# 90                   -0.879428                  -1.605096
# 106                   0.187094                  -1.566316
# 171                   0.393227                  -1.205747
# 84                    0.622318                  -1.161224
# 131                   0.193799                  -1.158304
# 49                   -0.266918                  -1.143775
# 2                    -0.573735                  -1.015261
# 60                   -0.257647                  -0.961918
# 117                  -0.149997                  -0.925156
# 11                    2.116863                  -0.810500
# 129                  -0.758557                  -0.780119
# 181                  -0.205961                  -0.774031
# 23                   -0.319986                  -0.766703
# 163                   2.718519                  -0.702557
# 118                   0.243643                  -0.673254
# 21                    1.387236                  -0.657376
